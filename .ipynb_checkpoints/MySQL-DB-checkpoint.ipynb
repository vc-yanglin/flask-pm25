# %% [markdown]
# ### 讀取PM2.5數據TO MYSQL

# %%
import pandas as pd
import pymysql

# %%
api_url="https://data.moenv.gov.tw/api/v2/aqx_p_02?api_key=540e2ca4-41e1-4186-8497-fdd67024ac44&limit=1000&sort=datacreationdate%20desc&format=CSV"

# %%
df=pd.read_csv(api_url)
df
# Out:
#     site county  pm25  datacreationdate itemunit
# 0     員林    彰化縣  26.0  2025-05-02 18:00    μg/m3
# 1     大城    彰化縣  29.0  2025-05-02 18:00    μg/m3
# 2    富貴角    新北市  21.0  2025-05-02 18:00    μg/m3
# 3     麥寮    雲林縣  27.0  2025-05-02 18:00    μg/m3
# 4     關山    臺東縣  21.0  2025-05-02 18:00    μg/m3
# ..   ...    ...   ...               ...      ...
# 995   平鎮    桃園市  20.0  2025-05-02 06:00    μg/m3
# 996   觀音    桃園市  23.0  2025-05-02 06:00    μg/m3
# 997   大園    桃園市  20.0  2025-05-02 06:00    μg/m3
# 998   桃園    桃園市  19.0  2025-05-02 06:00    μg/m3
# 999   大同    臺北市  19.0  2025-05-02 06:00    μg/m3
#
# [1000 rows x 5 columns]

# %% [markdown]
# ### 轉換時間格式刪除空值

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   site              1000 non-null   object
#  1   county            1000 non-null   object
#  2   pm25              982 non-null    float64
#  3   datacreationdate  1000 non-null   object
#  4   itemunit          1000 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 39.2+ KB

# %%
df["datacreationdate"]=pd.to_datetime(df["datacreationdate"])
df
# Out:
#     site county  pm25    datacreationdate itemunit
# 0     員林    彰化縣  26.0 2025-05-02 18:00:00    μg/m3
# 1     大城    彰化縣  29.0 2025-05-02 18:00:00    μg/m3
# 2    富貴角    新北市  21.0 2025-05-02 18:00:00    μg/m3
# 3     麥寮    雲林縣  27.0 2025-05-02 18:00:00    μg/m3
# 4     關山    臺東縣  21.0 2025-05-02 18:00:00    μg/m3
# ..   ...    ...   ...                 ...      ...
# 995   平鎮    桃園市  20.0 2025-05-02 06:00:00    μg/m3
# 996   觀音    桃園市  23.0 2025-05-02 06:00:00    μg/m3
# 997   大園    桃園市  20.0 2025-05-02 06:00:00    μg/m3
# 998   桃園    桃園市  19.0 2025-05-02 06:00:00    μg/m3
# 999   大同    臺北市  19.0 2025-05-02 06:00:00    μg/m3
#
# [1000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   site              1000 non-null   object
#  1   county            1000 non-null   object
#  2   pm25              982 non-null    float64
#  3   datacreationdate  1000 non-null   datetime64[ns]
#  4   itemunit          1000 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 39.2+ KB

# %% [markdown]
# ### isna()比對
# - df.dropna()

# %%
df1=df.drop(df[df["pm25"].isna()].index)
df1
# Out:
#     site county  pm25    datacreationdate itemunit
# 0     員林    彰化縣  26.0 2025-05-02 18:00:00    μg/m3
# 1     大城    彰化縣  29.0 2025-05-02 18:00:00    μg/m3
# 2    富貴角    新北市  21.0 2025-05-02 18:00:00    μg/m3
# 3     麥寮    雲林縣  27.0 2025-05-02 18:00:00    μg/m3
# 4     關山    臺東縣  21.0 2025-05-02 18:00:00    μg/m3
# ..   ...    ...   ...                 ...      ...
# 995   平鎮    桃園市  20.0 2025-05-02 06:00:00    μg/m3
# 996   觀音    桃園市  23.0 2025-05-02 06:00:00    μg/m3
# 997   大園    桃園市  20.0 2025-05-02 06:00:00    μg/m3
# 998   桃園    桃園市  19.0 2025-05-02 06:00:00    μg/m3
# 999   大同    臺北市  19.0 2025-05-02 06:00:00    μg/m3
#
# [982 rows x 5 columns]

# %% [markdown]
# ### 最新時間資料

# %%
latest_time=df1["datacreationdate"].max()
latest_time
# Out:
# Timestamp('2025-05-02 18:00:00')

# %%
df1[df1["datacreationdate"]==latest_time]
# Out:
#    site county  pm25    datacreationdate itemunit
# 0    員林    彰化縣  26.0 2025-05-02 18:00:00    μg/m3
# 1    大城    彰化縣  29.0 2025-05-02 18:00:00    μg/m3
# 2   富貴角    新北市  21.0 2025-05-02 18:00:00    μg/m3
# 3    麥寮    雲林縣  27.0 2025-05-02 18:00:00    μg/m3
# 4    關山    臺東縣  21.0 2025-05-02 18:00:00    μg/m3
# ..  ...    ...   ...                 ...      ...
# 73   板橋    新北市  19.0 2025-05-02 18:00:00    μg/m3
# 74   土城    新北市  18.0 2025-05-02 18:00:00    μg/m3
# 75   新店    新北市  15.0 2025-05-02 18:00:00    μg/m3
# 76   汐止    新北市  16.0 2025-05-02 18:00:00    μg/m3
# 77   基隆    基隆市  16.0 2025-05-02 18:00:00    μg/m3
#
# [77 rows x 5 columns]

# %% [markdown]
# ### 找出臺北市所有站點平均PM2.5值

# %%
df1["county"].unique()
# Out:
# array(['彰化縣', '新北市', '雲林縣', '臺東縣', '澎湖縣', '金門縣', '連江縣', '南投縣', '高雄市',
#        '桃園市', '宜蘭縣', '臺北市', '花蓮縣', '屏東縣', '臺南市', '嘉義市', '嘉義縣', '臺中市',
#        '苗栗縣', '新竹市', '新竹縣', '基隆市'], dtype=object)

# %%
df1.groupby("county").get_group("臺北市").groupby("site")["pm25"].mean()
# Out:
# site
# 中山    22.916667
# 古亭    18.833333
# 士林    20.000000
# 大同    21.923077
# 松山    22.333333
# 萬華    21.181818
# 陽明    19.384615
# Name: pm25, dtype: float64

# %%
taipei=df1[df1["county"]=="臺北市"]
taipei
# Out:
#     site county  pm25    datacreationdate itemunit
# 16    陽明    臺北市  19.0 2025-05-02 18:00:00    μg/m3
# 63    大同    臺北市  23.0 2025-05-02 18:00:00    μg/m3
# 64    松山    臺北市  20.0 2025-05-02 18:00:00    μg/m3
# 65    古亭    臺北市  19.0 2025-05-02 18:00:00    μg/m3
# 66    萬華    臺北市  20.0 2025-05-02 18:00:00    μg/m3
# ..   ...    ...   ...                 ...      ...
# 924   萬華    臺北市  19.0 2025-05-02 07:00:00    μg/m3
# 925   中山    臺北市  15.0 2025-05-02 07:00:00    μg/m3
# 926   士林    臺北市  22.0 2025-05-02 07:00:00    μg/m3
# 952   陽明    臺北市  14.0 2025-05-02 06:00:00    μg/m3
# 999   大同    臺北市  19.0 2025-05-02 06:00:00    μg/m3
#
# [85 rows x 5 columns]

# %%
taipei.groupby("site")["pm25"].mean()
# Out:
# site
# 中山    22.916667
# 古亭    18.833333
# 士林    20.000000
# 大同    21.923077
# 松山    22.333333
# 萬華    21.181818
# 陽明    19.384615
# Name: pm25, dtype: float64

# %% [markdown]
# ### 寫入資料庫(mysql)

# %%
conn=pymysql.connect(
    host="127.0.0.1",
    port=3306,
    user="root",
    passwd="12345678",
    db="demo"
)

cur=conn.cursor()
cur

# %%
cur.execute("show tables;")
# Out:
# 1

# %%
cur.fetchall()
# Out:
# (('pm25',),)

# %% [markdown]
# ### 建立資料表

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 982 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   site              982 non-null    object
#  1   county            982 non-null    object
#  2   pm25              982 non-null    float64
#  3   datacreationdate  982 non-null    datetime64[ns]
#  4   itemunit          982 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 46.0+ KB

# %% [markdown]
# ### 增加約束欄位避免重複

# %%
sqlstr='''
create table if not exists pm25(
id int auto_increment primary key,
site varchar(20) not null,
county varchar(50) not null,
pm25 float not null,
datacreationdate datetime not null,
itemunit varchar(10),
unique key uq_site_datetime (site,datacreationdate)
);

'''
print(sqlstr)
# Out:
# create table if not exists pm25(
# id int auto_increment primary key,
# site varchar(20) not null,
# county varchar(50) not null,
# pm25 float not null,
# datacreationdate datetime not null,
# itemunit varchar(10),
# unique key uq_site_datetime (site,datacreationdate)
# );

# %%
cur.execute(sqlstr)
conn.commit()

# %% [markdown]
# ### 寫入資料
# - 使用%s佔位跟ignore

# %%
sqlstr='''
insert ignore into pm25(site,county,pm25,datacreationdate,itemunit) 
values(%s,%s,%s,%s,%s)
'''

# %%
values=df1.values.tolist()
values
# Out:
# [['員林', '彰化縣', 26.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['大城', '彰化縣', 29.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['富貴角', '新北市', 21.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['麥寮', '雲林縣', 27.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['關山', '臺東縣', 21.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['馬公', '澎湖縣', 23.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['金門', '金門縣', 20.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['馬祖', '連江縣', 27.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['埔里', '南投縣', 24.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['復興', '高雄市', 19.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['永和', '新北市', 18.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['竹山', '南投縣', 25.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['中壢', '桃園市', 18.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['三重', '新北市', 28.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['冬山', '宜蘭縣', 23.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 23.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['陽明', '臺北市', 19.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['花蓮', '花蓮縣', 16.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['臺東', '臺東縣', 15.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['恆春', '屏東縣', 13.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['潮州', '屏東縣', 19.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['屏東', '屏東縣', 22.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['小港', '高雄市', 17.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['前鎮', '高雄市', 14.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['前金', '高雄市', 16.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['左營', '高雄市', 20.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['楠梓', '高雄市', 18.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['林園', '高雄市', 18.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['大寮', '高雄市', 16.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['鳳山', '高雄市', 23.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['仁武', '高雄市', 19.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['橋頭', '高雄市', 23.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['美濃', '高雄市', 14.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['臺南', '臺南市', 23.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['安南', '臺南市', 19.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['善化', '臺南市', 22.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['新營', '臺南市', 21.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['嘉義', '嘉義市', 25.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['臺西', '雲林縣', 24.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['朴子', '嘉義縣', 20.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['新港', '嘉義縣', 30.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['崙背', '雲林縣', 26.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['斗六', '雲林縣', 29.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['南投', '南投縣', 28.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['二林', '彰化縣', 36.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['線西', '彰化縣', 30.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['彰化', '彰化縣', 28.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['西屯', '臺中市', 33.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['忠明', '臺中市', 31.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['大里', '臺中市', 26.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['沙鹿', '臺中市', 37.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['三義', '苗栗縣', 23.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['苗栗', '苗栗縣', 23.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['頭份', '苗栗縣', 22.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['新竹', '新竹市', 19.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['竹東', '新竹縣', 24.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['湖口', '新竹縣', 24.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['龍潭', '桃園市', 17.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['平鎮', '桃園市', 15.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['觀音', '桃園市', 17.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['大園', '桃園市', 18.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['桃園', '桃園市', 17.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['大同', '臺北市', 23.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['松山', '臺北市', 20.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['古亭', '臺北市', 19.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['萬華', '臺北市', 20.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['中山', '臺北市', 28.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['士林', '臺北市', 17.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['淡水', '新北市', 21.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['林口', '新北市', 20.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['菜寮', '新北市', 19.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['新莊', '新北市', 19.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['板橋', '新北市', 19.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['土城', '新北市', 18.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['新店', '新北市', 15.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['汐止', '新北市', 16.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['基隆', '基隆市', 16.0, Timestamp('2025-05-02 18:00:00'), 'μg/m3'],
#  ['員林', '彰化縣', 27.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['大城', '彰化縣', 23.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['富貴角', '新北市', 21.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['麥寮', '雲林縣', 22.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['關山', '臺東縣', 15.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['馬公', '澎湖縣', 20.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['金門', '金門縣', 22.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['馬祖', '連江縣', 28.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['埔里', '南投縣', 27.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['復興', '高雄市', 17.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['永和', '新北市', 19.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['竹山', '南投縣', 29.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['中壢', '桃園市', 24.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['三重', '新北市', 22.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['冬山', '宜蘭縣', 19.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 23.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['陽明', '臺北市', 23.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['花蓮', '花蓮縣', 21.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['臺東', '臺東縣', 11.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['恆春', '屏東縣', 14.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['潮州', '屏東縣', 21.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['屏東', '屏東縣', 19.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['小港', '高雄市', 18.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['前鎮', '高雄市', 14.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['前金', '高雄市', 13.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['左營', '高雄市', 12.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['楠梓', '高雄市', 20.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['林園', '高雄市', 21.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['大寮', '高雄市', 21.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['鳳山', '高雄市', 21.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['仁武', '高雄市', 19.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['橋頭', '高雄市', 23.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['美濃', '高雄市', 23.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['臺南', '臺南市', 26.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['安南', '臺南市', 26.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['善化', '臺南市', 22.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['新營', '臺南市', 19.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['嘉義', '嘉義市', 22.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['臺西', '雲林縣', 23.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['朴子', '嘉義縣', 22.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['新港', '嘉義縣', 22.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['崙背', '雲林縣', 25.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['斗六', '雲林縣', 21.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['南投', '南投縣', 23.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['二林', '彰化縣', 25.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['線西', '彰化縣', 27.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['彰化', '彰化縣', 28.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['西屯', '臺中市', 21.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['忠明', '臺中市', 21.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['大里', '臺中市', 24.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['沙鹿', '臺中市', 32.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['三義', '苗栗縣', 22.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['苗栗', '苗栗縣', 15.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['頭份', '苗栗縣', 22.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['新竹', '新竹市', 19.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['竹東', '新竹縣', 20.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['湖口', '新竹縣', 24.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['龍潭', '桃園市', 15.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['平鎮', '桃園市', 13.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['觀音', '桃園市', 14.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['大園', '桃園市', 18.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['桃園', '桃園市', 15.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['大同', '臺北市', 25.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['松山', '臺北市', 23.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['古亭', '臺北市', 18.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['萬華', '臺北市', 26.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['中山', '臺北市', 27.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['士林', '臺北市', 17.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['淡水', '新北市', 25.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['林口', '新北市', 19.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['菜寮', '新北市', 22.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['新莊', '新北市', 17.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['板橋', '新北市', 20.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['土城', '新北市', 14.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['新店', '新北市', 17.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['汐止', '新北市', 18.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['基隆', '基隆市', 21.0, Timestamp('2025-05-02 17:00:00'), 'μg/m3'],
#  ['員林', '彰化縣', 21.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['大城', '彰化縣', 26.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['富貴角', '新北市', 22.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['麥寮', '雲林縣', 24.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['關山', '臺東縣', 15.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['馬公', '澎湖縣', 25.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['金門', '金門縣', 18.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['馬祖', '連江縣', 27.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['埔里', '南投縣', 35.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['復興', '高雄市', 12.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['永和', '新北市', 24.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['竹山', '南投縣', 28.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['中壢', '桃園市', 21.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['三重', '新北市', 28.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['冬山', '宜蘭縣', 18.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 28.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['陽明', '臺北市', 20.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['花蓮', '花蓮縣', 16.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['臺東', '臺東縣', 10.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['恆春', '屏東縣', 11.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['潮州', '屏東縣', 15.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['屏東', '屏東縣', 15.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['小港', '高雄市', 15.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['前鎮', '高雄市', 15.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['前金', '高雄市', 13.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['左營', '高雄市', 12.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['楠梓', '高雄市', 20.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['林園', '高雄市', 16.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['大寮', '高雄市', 20.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['鳳山', '高雄市', 21.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['仁武', '高雄市', 17.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['橋頭', '高雄市', 20.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['美濃', '高雄市', 23.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['臺南', '臺南市', 24.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['安南', '臺南市', 26.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['善化', '臺南市', 25.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['新營', '臺南市', 20.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['嘉義', '嘉義市', 22.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['臺西', '雲林縣', 16.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['朴子', '嘉義縣', 24.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['新港', '嘉義縣', 22.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['崙背', '雲林縣', 20.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['斗六', '雲林縣', 19.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['南投', '南投縣', 21.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['二林', '彰化縣', 23.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['線西', '彰化縣', 29.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['彰化', '彰化縣', 21.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['西屯', '臺中市', 19.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['忠明', '臺中市', 23.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['大里', '臺中市', 24.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['沙鹿', '臺中市', 32.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['三義', '苗栗縣', 16.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['苗栗', '苗栗縣', 21.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['頭份', '苗栗縣', 23.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['新竹', '新竹市', 24.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['竹東', '新竹縣', 20.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['湖口', '新竹縣', 17.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['龍潭', '桃園市', 17.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['平鎮', '桃園市', 16.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['觀音', '桃園市', 20.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['大園', '桃園市', 20.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['桃園', '桃園市', 17.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['大同', '臺北市', 23.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['松山', '臺北市', 23.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['古亭', '臺北市', 19.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['萬華', '臺北市', 25.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['中山', '臺北市', 26.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['士林', '臺北市', 21.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['淡水', '新北市', 23.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['林口', '新北市', 21.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['菜寮', '新北市', 24.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['新莊', '新北市', 20.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['板橋', '新北市', 19.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['土城', '新北市', 17.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['新店', '新北市', 21.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['汐止', '新北市', 20.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['基隆', '基隆市', 21.0, Timestamp('2025-05-02 16:00:00'), 'μg/m3'],
#  ['員林', '彰化縣', 23.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['大城', '彰化縣', 21.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['富貴角', '新北市', 23.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['麥寮', '雲林縣', 19.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['關山', '臺東縣', 11.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['馬公', '澎湖縣', 20.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['金門', '金門縣', 19.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['馬祖', '連江縣', 23.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['埔里', '南投縣', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['復興', '高雄市', 19.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['永和', '新北市', 23.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['竹山', '南投縣', 29.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['中壢', '桃園市', 16.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['三重', '新北市', 29.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['冬山', '宜蘭縣', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 21.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['陽明', '臺北市', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['花蓮', '花蓮縣', 13.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['臺東', '臺東縣', 10.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['恆春', '屏東縣', 16.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['潮州', '屏東縣', 20.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['屏東', '屏東縣', 17.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['小港', '高雄市', 19.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['前鎮', '高雄市', 17.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['前金', '高雄市', 10.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['左營', '高雄市', 12.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['楠梓', '高雄市', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['林園', '高雄市', 21.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['大寮', '高雄市', 14.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['鳳山', '高雄市', 20.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['仁武', '高雄市', 21.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['橋頭', '高雄市', 21.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['美濃', '高雄市', 20.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['臺南', '臺南市', 21.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['安南', '臺南市', 24.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['新營', '臺南市', 26.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['嘉義', '嘉義市', 18.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['臺西', '雲林縣', 18.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['朴子', '嘉義縣', 21.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['新港', '嘉義縣', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['崙背', '雲林縣', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['斗六', '雲林縣', 21.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['南投', '南投縣', 28.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['二林', '彰化縣', 24.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['線西', '彰化縣', 18.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['彰化', '彰化縣', 21.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['西屯', '臺中市', 27.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['忠明', '臺中市', 21.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['大里', '臺中市', 27.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['沙鹿', '臺中市', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['三義', '苗栗縣', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['苗栗', '苗栗縣', 14.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['頭份', '苗栗縣', 19.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['新竹', '新竹市', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['竹東', '新竹縣', 23.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['湖口', '新竹縣', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['龍潭', '桃園市', 12.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['平鎮', '桃園市', 13.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['觀音', '桃園市', 15.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['大園', '桃園市', 18.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['桃園', '桃園市', 21.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['大同', '臺北市', 25.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['松山', '臺北市', 25.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['古亭', '臺北市', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['萬華', '臺北市', 21.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['中山', '臺北市', 24.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['士林', '臺北市', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['淡水', '新北市', 23.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['林口', '新北市', 25.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['菜寮', '新北市', 23.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['新莊', '新北市', 20.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['板橋', '新北市', 16.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['土城', '新北市', 20.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['新店', '新北市', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['汐止', '新北市', 24.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['基隆', '基隆市', 22.0, Timestamp('2025-05-02 15:00:00'), 'μg/m3'],
#  ['員林', '彰化縣', 23.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['大城', '彰化縣', 17.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['富貴角', '新北市', 22.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['麥寮', '雲林縣', 17.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['關山', '臺東縣', 12.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['馬公', '澎湖縣', 20.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['金門', '金門縣', 20.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['馬祖', '連江縣', 26.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['埔里', '南投縣', 14.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['復興', '高雄市', 14.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['永和', '新北市', 22.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['竹山', '南投縣', 29.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['中壢', '桃園市', 17.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['三重', '新北市', 23.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['冬山', '宜蘭縣', 19.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 20.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['陽明', '臺北市', 22.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['花蓮', '花蓮縣', 19.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['臺東', '臺東縣', 7.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['恆春', '屏東縣', 11.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['潮州', '屏東縣', 19.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['屏東', '屏東縣', 18.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['小港', '高雄市', 18.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['前鎮', '高雄市', 22.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['前金', '高雄市', 19.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['左營', '高雄市', 15.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['楠梓', '高雄市', 24.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['林園', '高雄市', 17.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['大寮', '高雄市', 20.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['鳳山', '高雄市', 17.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['仁武', '高雄市', 17.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['橋頭', '高雄市', 25.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['美濃', '高雄市', 19.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['臺南', '臺南市', 26.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['安南', '臺南市', 25.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['善化', '臺南市', 22.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['新營', '臺南市', 26.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['嘉義', '嘉義市', 25.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['臺西', '雲林縣', 18.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['朴子', '嘉義縣', 28.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['新港', '嘉義縣', 21.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['崙背', '雲林縣', 17.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['斗六', '雲林縣', 27.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['南投', '南投縣', 26.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['二林', '彰化縣', 18.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['線西', '彰化縣', 18.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['彰化', '彰化縣', 22.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['西屯', '臺中市', 22.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['忠明', '臺中市', 22.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['大里', '臺中市', 27.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['沙鹿', '臺中市', 23.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['三義', '苗栗縣', 23.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['苗栗', '苗栗縣', 19.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['頭份', '苗栗縣', 18.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['新竹', '新竹市', 18.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['竹東', '新竹縣', 19.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['湖口', '新竹縣', 29.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['龍潭', '桃園市', 15.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['平鎮', '桃園市', 13.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['觀音', '桃園市', 17.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['大園', '桃園市', 17.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['桃園', '桃園市', 18.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['大同', '臺北市', 22.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['松山', '臺北市', 22.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['古亭', '臺北市', 20.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['萬華', '臺北市', 21.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['中山', '臺北市', 25.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['士林', '臺北市', 19.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['淡水', '新北市', 23.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['林口', '新北市', 17.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['菜寮', '新北市', 22.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['土城', '新北市', 19.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['新店', '新北市', 22.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['汐止', '新北市', 27.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['基隆', '基隆市', 20.0, Timestamp('2025-05-02 14:00:00'), 'μg/m3'],
#  ['員林', '彰化縣', 29.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['大城', '彰化縣', 22.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['富貴角', '新北市', 23.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['麥寮', '雲林縣', 20.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['關山', '臺東縣', 5.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['馬公', '澎湖縣', 12.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['金門', '金門縣', 28.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['馬祖', '連江縣', 30.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['埔里', '南投縣', 12.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['復興', '高雄市', 17.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['永和', '新北市', 22.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['竹山', '南投縣', 22.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['中壢', '桃園市', 20.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['三重', '新北市', 25.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['冬山', '宜蘭縣', 18.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 18.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['陽明', '臺北市', 21.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['花蓮', '花蓮縣', 17.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['臺東', '臺東縣', 10.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['恆春', '屏東縣', 7.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['潮州', '屏東縣', 22.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['屏東', '屏東縣', 28.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['小港', '高雄市', 17.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['前鎮', '高雄市', 16.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['前金', '高雄市', 16.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['左營', '高雄市', 18.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['楠梓', '高雄市', 21.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['林園', '高雄市', 18.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['大寮', '高雄市', 15.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['鳳山', '高雄市', 17.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['仁武', '高雄市', 19.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['橋頭', '高雄市', 22.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['美濃', '高雄市', 19.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['臺南', '臺南市', 24.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['安南', '臺南市', 23.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['善化', '臺南市', 18.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['嘉義', '嘉義市', 19.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['臺西', '雲林縣', 21.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['朴子', '嘉義縣', 23.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['新港', '嘉義縣', 23.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['崙背', '雲林縣', 24.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['斗六', '雲林縣', 28.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['南投', '南投縣', 23.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['二林', '彰化縣', 22.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['線西', '彰化縣', 19.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['彰化', '彰化縣', 21.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['西屯', '臺中市', 22.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['忠明', '臺中市', 22.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['大里', '臺中市', 26.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['沙鹿', '臺中市', 22.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['三義', '苗栗縣', 25.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['苗栗', '苗栗縣', 19.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['頭份', '苗栗縣', 27.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['新竹', '新竹市', 21.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['竹東', '新竹縣', 11.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['湖口', '新竹縣', 16.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['龍潭', '桃園市', 14.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['平鎮', '桃園市', 14.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['觀音', '桃園市', 17.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['大園', '桃園市', 21.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['桃園', '桃園市', 17.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['大同', '臺北市', 21.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['松山', '臺北市', 24.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['古亭', '臺北市', 19.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['萬華', '臺北市', 21.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['中山', '臺北市', 23.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['士林', '臺北市', 21.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['淡水', '新北市', 19.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['林口', '新北市', 20.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['菜寮', '新北市', 23.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['新莊', '新北市', 24.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['板橋', '新北市', 17.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['土城', '新北市', 20.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['新店', '新北市', 20.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['汐止', '新北市', 26.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['基隆', '基隆市', 21.0, Timestamp('2025-05-02 13:00:00'), 'μg/m3'],
#  ['員林', '彰化縣', 30.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['大城', '彰化縣', 23.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['富貴角', '新北市', 29.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['麥寮', '雲林縣', 18.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['關山', '臺東縣', 9.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['馬公', '澎湖縣', 15.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['金門', '金門縣', 42.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['馬祖', '連江縣', 28.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['埔里', '南投縣', 10.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['復興', '高雄市', 17.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['永和', '新北市', 20.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['竹山', '南投縣', 24.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['中壢', '桃園市', 23.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['三重', '新北市', 24.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['冬山', '宜蘭縣', 20.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 16.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['陽明', '臺北市', 21.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['花蓮', '花蓮縣', 16.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['臺東', '臺東縣', 10.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['恆春', '屏東縣', 5.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['潮州', '屏東縣', 22.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['屏東', '屏東縣', 26.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['小港', '高雄市', 24.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['左營', '高雄市', 23.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['楠梓', '高雄市', 25.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['林園', '高雄市', 23.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['大寮', '高雄市', 22.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['鳳山', '高雄市', 27.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['仁武', '高雄市', 24.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['橋頭', '高雄市', 20.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['美濃', '高雄市', 20.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['安南', '臺南市', 17.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['善化', '臺南市', 18.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['新營', '臺南市', 16.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['嘉義', '嘉義市', 22.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['臺西', '雲林縣', 22.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['朴子', '嘉義縣', 27.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['新港', '嘉義縣', 26.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['崙背', '雲林縣', 24.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['斗六', '雲林縣', 24.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['南投', '南投縣', 20.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['二林', '彰化縣', 25.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['線西', '彰化縣', 23.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['西屯', '臺中市', 19.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['忠明', '臺中市', 17.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['大里', '臺中市', 23.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['沙鹿', '臺中市', 25.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['三義', '苗栗縣', 21.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['苗栗', '苗栗縣', 23.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['頭份', '苗栗縣', 22.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['新竹', '新竹市', 14.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['竹東', '新竹縣', 20.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['湖口', '新竹縣', 19.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['龍潭', '桃園市', 18.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['平鎮', '桃園市', 18.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['觀音', '桃園市', 20.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['大園', '桃園市', 16.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['桃園', '桃園市', 17.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['大同', '臺北市', 27.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['松山', '臺北市', 30.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['古亭', '臺北市', 23.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['萬華', '臺北市', 25.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['中山', '臺北市', 24.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['士林', '臺北市', 19.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['淡水', '新北市', 24.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['林口', '新北市', 22.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['菜寮', '新北市', 26.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['新莊', '新北市', 23.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['板橋', '新北市', 18.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['土城', '新北市', 24.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['新店', '新北市', 18.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['汐止', '新北市', 22.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['基隆', '基隆市', 26.0, Timestamp('2025-05-02 12:00:00'), 'μg/m3'],
#  ['員林', '彰化縣', 25.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['大城', '彰化縣', 18.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['富貴角', '新北市', 27.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['麥寮', '雲林縣', 21.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['關山', '臺東縣', 9.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['馬公', '澎湖縣', 18.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['金門', '金門縣', 38.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['馬祖', '連江縣', 30.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['埔里', '南投縣', 16.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['復興', '高雄市', 25.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['永和', '新北市', 24.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['竹山', '南投縣', 20.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['中壢', '桃園市', 17.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['三重', '新北市', 27.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['冬山', '宜蘭縣', 17.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 23.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['陽明', '臺北市', 19.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['花蓮', '花蓮縣', 16.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['臺東', '臺東縣', 7.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['恆春', '屏東縣', 5.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['潮州', '屏東縣', 16.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['屏東', '屏東縣', 22.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['小港', '高雄市', 29.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['前鎮', '高雄市', 28.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['左營', '高雄市', 26.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['楠梓', '高雄市', 26.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['林園', '高雄市', 26.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['大寮', '高雄市', 28.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['鳳山', '高雄市', 25.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['仁武', '高雄市', 27.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['橋頭', '高雄市', 27.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['美濃', '高雄市', 16.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['臺南', '臺南市', 21.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['安南', '臺南市', 19.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['善化', '臺南市', 19.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['新營', '臺南市', 18.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['嘉義', '嘉義市', 21.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['臺西', '雲林縣', 19.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['朴子', '嘉義縣', 25.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['新港', '嘉義縣', 25.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['崙背', '雲林縣', 24.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['斗六', '雲林縣', 21.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['南投', '南投縣', 18.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['二林', '彰化縣', 23.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['線西', '彰化縣', 26.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['彰化', '彰化縣', 20.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['西屯', '臺中市', 19.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['忠明', '臺中市', 26.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['大里', '臺中市', 24.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['沙鹿', '臺中市', 25.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['三義', '苗栗縣', 17.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['苗栗', '苗栗縣', 20.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['頭份', '苗栗縣', 20.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['新竹', '新竹市', 17.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['竹東', '新竹縣', 15.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['湖口', '新竹縣', 17.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['龍潭', '桃園市', 21.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['平鎮', '桃園市', 17.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['觀音', '桃園市', 25.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['大園', '桃園市', 21.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['桃園', '桃園市', 15.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['大同', '臺北市', 24.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['松山', '臺北市', 22.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['古亭', '臺北市', 16.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['萬華', '臺北市', 19.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['中山', '臺北市', 27.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['士林', '臺北市', 26.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['淡水', '新北市', 18.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['林口', '新北市', 21.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['菜寮', '新北市', 25.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['新莊', '新北市', 20.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['板橋', '新北市', 18.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['土城', '新北市', 22.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['新店', '新北市', 19.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['汐止', '新北市', 22.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['基隆', '基隆市', 24.0, Timestamp('2025-05-02 11:00:00'), 'μg/m3'],
#  ['員林', '彰化縣', 23.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['大城', '彰化縣', 19.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['富貴角', '新北市', 26.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['麥寮', '雲林縣', 19.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['關山', '臺東縣', 11.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['馬公', '澎湖縣', 20.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['金門', '金門縣', 44.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['馬祖', '連江縣', 27.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['埔里', '南投縣', 15.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['復興', '高雄市', 29.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['永和', '新北市', 20.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['竹山', '南投縣', 23.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['中壢', '桃園市', 19.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['三重', '新北市', 30.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['冬山', '宜蘭縣', 19.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 18.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['陽明', '臺北市', 23.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['花蓮', '花蓮縣', 19.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['臺東', '臺東縣', 6.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['恆春', '屏東縣', 8.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['潮州', '屏東縣', 16.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['屏東', '屏東縣', 40.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['小港', '高雄市', 30.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['前鎮', '高雄市', 28.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['前金', '高雄市', 21.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['左營', '高雄市', 22.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['楠梓', '高雄市', 23.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['林園', '高雄市', 29.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['大寮', '高雄市', 28.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['鳳山', '高雄市', 30.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['仁武', '高雄市', 28.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['橋頭', '高雄市', 27.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['美濃', '高雄市', 18.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['臺南', '臺南市', 20.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['安南', '臺南市', 23.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['善化', '臺南市', 23.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['新營', '臺南市', 23.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['嘉義', '嘉義市', 20.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['臺西', '雲林縣', 16.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['朴子', '嘉義縣', 21.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['新港', '嘉義縣', 18.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['崙背', '雲林縣', 27.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['斗六', '雲林縣', 25.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['南投', '南投縣', 19.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['二林', '彰化縣', 25.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['線西', '彰化縣', 22.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['彰化', '彰化縣', 16.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['西屯', '臺中市', 18.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['忠明', '臺中市', 21.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['大里', '臺中市', 23.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['沙鹿', '臺中市', 24.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['豐原', '臺中市', 16.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['三義', '苗栗縣', 13.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['苗栗', '苗栗縣', 16.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['頭份', '苗栗縣', 18.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['新竹', '新竹市', 21.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['竹東', '新竹縣', 13.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['湖口', '新竹縣', 19.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['龍潭', '桃園市', 17.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['平鎮', '桃園市', 17.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['觀音', '桃園市', 21.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['大園', '桃園市', 13.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['桃園', '桃園市', 21.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['大同', '臺北市', 17.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['松山', '臺北市', 21.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['古亭', '臺北市', 20.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['中山', '臺北市', 21.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['士林', '臺北市', 22.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['淡水', '新北市', 22.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['林口', '新北市', 18.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['菜寮', '新北市', 21.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['新莊', '新北市', 21.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['板橋', '新北市', 16.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['土城', '新北市', 23.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['新店', '新北市', 21.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['汐止', '新北市', 19.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['基隆', '基隆市', 19.0, Timestamp('2025-05-02 10:00:00'), 'μg/m3'],
#  ['員林', '彰化縣', 22.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['大城', '彰化縣', 21.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['富貴角', '新北市', 20.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['麥寮', '雲林縣', 21.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['關山', '臺東縣', 11.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['馬公', '澎湖縣', 19.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['金門', '金門縣', 38.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['馬祖', '連江縣', 29.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['埔里', '南投縣', 19.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['復興', '高雄市', 24.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['永和', '新北市', 15.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['竹山', '南投縣', 18.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['中壢', '桃園市', 24.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['三重', '新北市', 24.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['冬山', '宜蘭縣', 15.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 20.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['陽明', '臺北市', 18.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['花蓮', '花蓮縣', 14.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['臺東', '臺東縣', 6.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['恆春', '屏東縣', 4.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['潮州', '屏東縣', 17.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['屏東', '屏東縣', 26.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['小港', '高雄市', 23.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['前鎮', '高雄市', 24.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['前金', '高雄市', 25.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['左營', '高雄市', 25.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['楠梓', '高雄市', 21.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['林園', '高雄市', 26.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['大寮', '高雄市', 26.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['鳳山', '高雄市', 27.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['仁武', '高雄市', 26.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['橋頭', '高雄市', 23.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['美濃', '高雄市', 16.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['臺南', '臺南市', 24.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['安南', '臺南市', 20.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['善化', '臺南市', 21.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['新營', '臺南市', 21.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['嘉義', '嘉義市', 22.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['臺西', '雲林縣', 15.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['朴子', '嘉義縣', 22.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['新港', '嘉義縣', 26.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['崙背', '雲林縣', 23.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['斗六', '雲林縣', 17.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['南投', '南投縣', 14.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['二林', '彰化縣', 23.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['線西', '彰化縣', 23.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['彰化', '彰化縣', 22.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['西屯', '臺中市', 16.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['忠明', '臺中市', 25.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['大里', '臺中市', 20.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['沙鹿', '臺中市', 20.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['豐原', '臺中市', 21.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['三義', '苗栗縣', 11.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['苗栗', '苗栗縣', 21.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['頭份', '苗栗縣', 20.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['新竹', '新竹市', 21.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['竹東', '新竹縣', 12.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['湖口', '新竹縣', 17.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['龍潭', '桃園市', 21.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['平鎮', '桃園市', 15.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['觀音', '桃園市', 17.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['大園', '桃園市', 15.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['桃園', '桃園市', 17.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['大同', '臺北市', 18.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['松山', '臺北市', 19.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['古亭', '臺北市', 14.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['萬華', '臺北市', 20.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['中山', '臺北市', 16.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['士林', '臺北市', 16.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['淡水', '新北市', 22.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['林口', '新北市', 23.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['菜寮', '新北市', 21.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['新莊', '新北市', 19.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['板橋', '新北市', 14.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['土城', '新北市', 20.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['新店', '新北市', 15.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['汐止', '新北市', 16.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['基隆', '基隆市', 17.0, Timestamp('2025-05-02 09:00:00'), 'μg/m3'],
#  ['員林', '彰化縣', 24.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['大城', '彰化縣', 26.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['富貴角', '新北市', 15.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['麥寮', '雲林縣', 31.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['關山', '臺東縣', 18.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['馬公', '澎湖縣', 15.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['金門', '金門縣', 60.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['馬祖', '連江縣', 27.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['埔里', '南投縣', 17.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['復興', '高雄市', 18.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['永和', '新北市', 16.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['竹山', '南投縣', 16.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['中壢', '桃園市', 22.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['三重', '新北市', 21.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['冬山', '宜蘭縣', 18.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 21.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['陽明', '臺北市', 16.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['花蓮', '花蓮縣', 10.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['臺東', '臺東縣', 11.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['恆春', '屏東縣', 7.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['潮州', '屏東縣', 20.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['屏東', '屏東縣', 22.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['小港', '高雄市', 29.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['前鎮', '高雄市', 19.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['前金', '高雄市', 21.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['左營', '高雄市', 25.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['楠梓', '高雄市', 24.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['林園', '高雄市', 28.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['大寮', '高雄市', 20.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['鳳山', '高雄市', 27.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['仁武', '高雄市', 24.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['橋頭', '高雄市', 30.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['美濃', '高雄市', 20.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['臺南', '臺南市', 20.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['安南', '臺南市', 24.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['善化', '臺南市', 28.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['新營', '臺南市', 29.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['嘉義', '嘉義市', 24.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['臺西', '雲林縣', 25.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['朴子', '嘉義縣', 29.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['新港', '嘉義縣', 31.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['崙背', '雲林縣', 36.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['斗六', '雲林縣', 22.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['南投', '南投縣', 21.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['二林', '彰化縣', 22.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['線西', '彰化縣', 23.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['彰化', '彰化縣', 19.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['西屯', '臺中市', 15.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['忠明', '臺中市', 21.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['大里', '臺中市', 23.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['沙鹿', '臺中市', 19.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['豐原', '臺中市', 13.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['三義', '苗栗縣', 16.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['苗栗', '苗栗縣', 22.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['頭份', '苗栗縣', 21.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['新竹', '新竹市', 18.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['竹東', '新竹縣', 15.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['湖口', '新竹縣', 21.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['龍潭', '桃園市', 20.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['平鎮', '桃園市', 17.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['觀音', '桃園市', 18.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['大園', '桃園市', 15.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['桃園', '桃園市', 20.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['大同', '臺北市', 21.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['松山', '臺北市', 22.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['古亭', '臺北市', 18.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['萬華', '臺北市', 16.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['中山', '臺北市', 19.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['士林', '臺北市', 18.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['淡水', '新北市', 20.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['林口', '新北市', 20.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['菜寮', '新北市', 17.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['新莊', '新北市', 18.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['板橋', '新北市', 18.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['土城', '新北市', 20.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['新店', '新北市', 20.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['汐止', '新北市', 15.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['基隆', '基隆市', 14.0, Timestamp('2025-05-02 08:00:00'), 'μg/m3'],
#  ['員林', '彰化縣', 20.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['大城', '彰化縣', 36.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['富貴角', '新北市', 18.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['麥寮', '雲林縣', 38.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['關山', '臺東縣', 16.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['馬公', '澎湖縣', 16.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['金門', '金門縣', 53.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['馬祖', '連江縣', 31.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['埔里', '南投縣', 18.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['復興', '高雄市', 17.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['永和', '新北市', 16.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['竹山', '南投縣', 23.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['中壢', '桃園市', 24.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['三重', '新北市', 21.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['冬山', '宜蘭縣', 15.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 16.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['陽明', '臺北市', 14.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['花蓮', '花蓮縣', 13.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['臺東', '臺東縣', 12.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['恆春', '屏東縣', 8.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['潮州', '屏東縣', 15.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['屏東', '屏東縣', 21.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['小港', '高雄市', 23.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['前鎮', '高雄市', 20.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['前金', '高雄市', 14.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['左營', '高雄市', 23.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['楠梓', '高雄市', 26.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['林園', '高雄市', 23.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['大寮', '高雄市', 21.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['鳳山', '高雄市', 30.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['仁武', '高雄市', 30.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['橋頭', '高雄市', 26.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['美濃', '高雄市', 12.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['臺南', '臺南市', 19.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['安南', '臺南市', 31.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['善化', '臺南市', 21.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['新營', '臺南市', 27.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['嘉義', '嘉義市', 22.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['臺西', '雲林縣', 40.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['朴子', '嘉義縣', 27.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['新港', '嘉義縣', 26.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['崙背', '雲林縣', 33.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['斗六', '雲林縣', 21.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['南投', '南投縣', 22.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['二林', '彰化縣', 30.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['線西', '彰化縣', 24.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['彰化', '彰化縣', 20.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['西屯', '臺中市', 20.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['忠明', '臺中市', 19.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['大里', '臺中市', 20.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['沙鹿', '臺中市', 19.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['豐原', '臺中市', 19.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['三義', '苗栗縣', 17.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['苗栗', '苗栗縣', 15.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['頭份', '苗栗縣', 23.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['新竹', '新竹市', 21.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['竹東', '新竹縣', 19.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['湖口', '新竹縣', 19.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['龍潭', '桃園市', 22.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['平鎮', '桃園市', 17.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['觀音', '桃園市', 25.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['大園', '桃園市', 17.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['桃園', '桃園市', 16.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['大同', '臺北市', 20.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['松山', '臺北市', 17.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['古亭', '臺北市', 18.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['萬華', '臺北市', 19.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['中山', '臺北市', 15.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['士林', '臺北市', 22.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['淡水', '新北市', 21.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['林口', '新北市', 13.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['菜寮', '新北市', 19.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['新莊', '新北市', 15.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['板橋', '新北市', 16.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['土城', '新北市', 20.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['新店', '新北市', 18.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['汐止', '新北市', 15.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['基隆', '基隆市', 12.0, Timestamp('2025-05-02 07:00:00'), 'μg/m3'],
#  ['員林', '彰化縣', 21.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['大城', '彰化縣', 41.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['富貴角', '新北市', 15.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['麥寮', '雲林縣', 37.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['關山', '臺東縣', 12.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['馬公', '澎湖縣', 11.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['金門', '金門縣', 48.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['馬祖', '連江縣', 35.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['埔里', '南投縣', 17.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['復興', '高雄市', 19.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['永和', '新北市', 18.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['竹山', '南投縣', 20.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['中壢', '桃園市', 18.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['三重', '新北市', 20.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['冬山', '宜蘭縣', 11.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 14.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['陽明', '臺北市', 14.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['花蓮', '花蓮縣', 16.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['臺東', '臺東縣', 12.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['恆春', '屏東縣', 6.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['潮州', '屏東縣', 13.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['屏東', '屏東縣', 21.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['小港', '高雄市', 21.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['前鎮', '高雄市', 19.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['前金', '高雄市', 17.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['左營', '高雄市', 16.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['楠梓', '高雄市', 23.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['林園', '高雄市', 20.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['大寮', '高雄市', 23.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['鳳山', '高雄市', 22.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['仁武', '高雄市', 28.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['橋頭', '高雄市', 25.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['美濃', '高雄市', 14.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['臺南', '臺南市', 18.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['安南', '臺南市', 26.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['善化', '臺南市', 23.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['新營', '臺南市', 27.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['嘉義', '嘉義市', 21.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['臺西', '雲林縣', 28.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['朴子', '嘉義縣', 28.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['新港', '嘉義縣', 29.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['崙背', '雲林縣', 32.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['斗六', '雲林縣', 22.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['南投', '南投縣', 19.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['二林', '彰化縣', 24.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['線西', '彰化縣', 24.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['彰化', '彰化縣', 21.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['西屯', '臺中市', 23.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['忠明', '臺中市', 19.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['大里', '臺中市', 23.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['沙鹿', '臺中市', 15.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['豐原', '臺中市', 14.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['三義', '苗栗縣', 14.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['苗栗', '苗栗縣', 20.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['頭份', '苗栗縣', 25.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['新竹', '新竹市', 19.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['竹東', '新竹縣', 20.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['湖口', '新竹縣', 26.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['龍潭', '桃園市', 19.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['平鎮', '桃園市', 20.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['觀音', '桃園市', 23.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['大園', '桃園市', 20.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['桃園', '桃園市', 19.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3'],
#  ['大同', '臺北市', 19.0, Timestamp('2025-05-02 06:00:00'), 'μg/m3']]

# %%
cur.execute(sqlstr,values[0])
conn.commit()

# %% [markdown]
# ### executemany 一次寫入多筆資料

# %%
cur.executemany(sqlstr,values)
conn.commit()

# %% [markdown]
# ### 群分資料SQL語法
# - 不重複 distinct

# %%
sqlstr="select distinct county from pm25;"
cur.execute(sqlstr)
cur.fetchall()
# Out:
# (('彰化縣',),
#  ('新北市',),
#  ('雲林縣',),
#  ('臺東縣',),
#  ('澎湖縣',),
#  ('金門縣',),
#  ('連江縣',),
#  ('南投縣',),
#  ('高雄市',),
#  ('桃園市',),
#  ('宜蘭縣',),
#  ('臺北市',),
#  ('花蓮縣',),
#  ('屏東縣',),
#  ('臺南市',),
#  ('嘉義市',),
#  ('嘉義縣',),
#  ('臺中市',),
#  ('苗栗縣',),
#  ('新竹市',),
#  ('新竹縣',),
#  ('基隆市',))

# %%
sqlstr="select distinct site from pm25;"
cur.execute(sqlstr)
rows=cur.fetchall()
rows
# Out:
# (('三義',),
#  ('三重',),
#  ('中壢',),
#  ('中山',),
#  ('二林',),
#  ('仁武',),
#  ('冬山',),
#  ('前金',),
#  ('前鎮',),
#  ('南投',),
#  ('古亭',),
#  ('員林',),
#  ('善化',),
#  ('嘉義',),
#  ('土城',),
#  ('埔里',),
#  ('基隆',),
#  ('士林',),
#  ('大同',),
#  ('大園',),
#  ('大城',),
#  ('大寮',),
#  ('大里',),
#  ('安南',),
#  ('宜蘭',),
#  ('富貴角',),
#  ('小港',),
#  ('屏東',),
#  ('崙背',),
#  ('左營',),
#  ('平鎮',),
#  ('彰化',),
#  ('復興',),
#  ('忠明',),
#  ('恆春',),
#  ('斗六',),
#  ('新店',),
#  ('新港',),
#  ('新營',),
#  ('新竹',),
#  ('新莊',),
#  ('朴子',),
#  ('松山',),
#  ('板橋',),
#  ('林口',),
#  ('林園',),
#  ('桃園',),
#  ('楠梓',),
#  ('橋頭',),
#  ('永和',),
#  ('汐止',),
#  ('沙鹿',),
#  ('淡水',),
#  ('湖口',),
#  ('潮州',),
#  ('竹山',),
#  ('竹東',),
#  ('線西',),
#  ('美濃',),
#  ('臺南',),
#  ('臺東',),
#  ('臺西',),
#  ('花蓮',),
#  ('苗栗',),
#  ('菜寮',),
#  ('萬華',),
#  ('萬里',),
#  ('西屯',),
#  ('觀音',),
#  ('豐原',),
#  ('金門',),
#  ('關山',),
#  ('陽明',),
#  ('頭份',),
#  ('馬公',),
#  ('馬祖',),
#  ('鳳山',),
#  ('麥寮',),
#  ('龍潭',))

# %%
[row[0] for row in rows]
# Out:
# ['三義',
#  '三重',
#  '中壢',
#  '中山',
#  '二林',
#  '仁武',
#  '冬山',
#  '前金',
#  '前鎮',
#  '南投',
#  '古亭',
#  '員林',
#  '善化',
#  '嘉義',
#  '土城',
#  '埔里',
#  '基隆',
#  '士林',
#  '大同',
#  '大園',
#  '大城',
#  '大寮',
#  '大里',
#  '安南',
#  '宜蘭',
#  '富貴角',
#  '小港',
#  '屏東',
#  '崙背',
#  '左營',
#  '平鎮',
#  '彰化',
#  '復興',
#  '忠明',
#  '恆春',
#  '斗六',
#  '新店',
#  '新港',
#  '新營',
#  '新竹',
#  '新莊',
#  '朴子',
#  '松山',
#  '板橋',
#  '林口',
#  '林園',
#  '桃園',
#  '楠梓',
#  '橋頭',
#  '永和',
#  '汐止',
#  '沙鹿',
#  '淡水',
#  '湖口',
#  '潮州',
#  '竹山',
#  '竹東',
#  '線西',
#  '美濃',
#  '臺南',
#  '臺東',
#  '臺西',
#  '花蓮',
#  '苗栗',
#  '菜寮',
#  '萬華',
#  '萬里',
#  '西屯',
#  '觀音',
#  '豐原',
#  '金門',
#  '關山',
#  '陽明',
#  '頭份',
#  '馬公',
#  '馬祖',
#  '鳳山',
#  '麥寮',
#  '龍潭']

# %% [markdown]
# ### 縣市平均PM2.5

# %%
df1.groupby("county")["pm25"].mean().sort_values(ascending=False)
# Out:
# county
# 金門縣    34.615385
# 連江縣    28.307692
# 嘉義縣    24.538462
# 彰化縣    23.765625
# 雲林縣    23.634615
# 臺南市    22.530612
# 臺中市    22.280702
# 嘉義市    21.769231
# 南投縣    21.384615
# 高雄市    20.947712
# 臺北市    20.929412
# 新北市    20.563910
# 苗栗縣    19.692308
# 新竹市    19.538462
# 基隆市    19.416667
# 新竹縣    19.269231
# 宜蘭縣    19.038462
# 桃園市    18.000000
# 澎湖縣    18.000000
# 屏東縣    16.589744
# 花蓮縣    15.846154
# 臺東縣    11.230769
# Name: pm25, dtype: float64

# %% [markdown]
# ### select from
# - group by   (群分)
# - order by   (排序)
# - asc,desc   (升/降)

# %%
sqlstr="""select county,ROUND(AVG(pm25),2) as avg_pm25
from pm25 
group by county 
order by avg_pm25 desc;
"""
cur.execute(sqlstr)
rows=cur.fetchall()
rows
# Out:
# (('金門縣', 29.5),
#  ('連江縣', 23.08),
#  ('臺中市', 21.3),
#  ('彰化縣', 21.04),
#  ('雲林縣', 19.23),
#  ('南投縣', 19.19),
#  ('嘉義縣', 19.14),
#  ('臺南市', 18.15),
#  ('新竹市', 17.92),
#  ('苗栗縣', 17.72),
#  ('高雄市', 17.7),
#  ('嘉義市', 17.08),
#  ('臺北市', 16.87),
#  ('新竹縣', 16.68),
#  ('桃園市', 16.26),
#  ('新北市', 16.18),
#  ('屏東縣', 14.45),
#  ('澎湖縣', 14.15),
#  ('宜蘭縣', 13.88),
#  ('花蓮縣', 12.05),
#  ('基隆市', 11.76),
#  ('臺東縣', 10.01))

# %% [markdown]
# ### 找出臺北市站點PM2.5平均數據

# %%
df1.groupby("county")["pm25"].mean()
# Out:
# county
# 南投縣    21.384615
# 嘉義市    21.769231
# 嘉義縣    24.538462
# 基隆市    19.416667
# 宜蘭縣    19.038462
# 屏東縣    16.589744
# 彰化縣    23.765625
# 新北市    20.563910
# 新竹市    19.538462
# 新竹縣    19.269231
# 桃園市    18.000000
# 澎湖縣    18.000000
# 臺中市    22.280702
# 臺北市    20.929412
# 臺南市    22.530612
# 臺東縣    11.230769
# 花蓮縣    15.846154
# 苗栗縣    19.692308
# 連江縣    28.307692
# 金門縣    34.615385
# 雲林縣    23.634615
# 高雄市    20.947712
# Name: pm25, dtype: float64

# %%
df1.groupby("county").get_group("臺北市").groupby("site")["pm25"].mean().round(2)
# Out:
# site
# 中山    22.92
# 古亭    18.83
# 士林    20.00
# 大同    21.92
# 松山    22.33
# 萬華    21.18
# 陽明    19.38
# Name: pm25, dtype: float64

# %%
sqlstr="""
select site,round(AVG(pm25),2) as avg_pm25
from pm25
where county='臺北市'
group by site
order by avg_pm25 desc
"""

cur.execute(sqlstr)
rows=cur.fetchall()
rows
# Out:
# (('大同', 20.16),
#  ('松山', 19.62),
#  ('中山', 17.92),
#  ('萬華', 15.78),
#  ('士林', 15.57),
#  ('古亭', 15.08),
#  ('陽明', 13.97))

# %%
conn.close()
